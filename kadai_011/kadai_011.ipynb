# %%
array = ["水","金","地","火","木","土","天","海","冥"]

#for文を使った処理
for i in array:
  print(i)

#While文を使った処理
j = 0
while j < len(array):
  print(array[j])
  j = j+1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
