# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(self.name)
    print(self.age)

human = Human("山田太郎", 20)
human.printinfo()
# Out:
# 山田太郎
# 20
