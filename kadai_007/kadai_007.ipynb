# %%
array = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです", "木曜日は晴れです", "金曜日は曇りです", "土曜日は曇りのち雨雨です", "日曜日は雷雨です"]
print(array[2])
# Out:
# 水曜日は晴れです

# %%
dictionary = {"mon":"晴れ", "tue":"雨", "wed":"晴れ", "thu":"晴れ", "fri":"曇り", "sat":"曇りのち雨", "sun":"sun"}
print(dictionary["wed"])
# Out:
# 晴れ
